# %%
from IPython.display import IFrame
import re
import requests
from bs4 import BeautifulSoup
import pprint
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Display website in Notebook
IFrame('https://reiseauskunft.bahn.de/bin/query.exe/dn?ld=43238&protocol=https:&seqnr=1&ident=ni.08329238.1580414184&rt=1&rememberSortType=minDeparture&jumpToDetails=yes&HWAI=CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;', width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://reiseauskunft.bahn.de/bin/query.exe/dn?ld=43238&protocol=https:&seqnr=1&ident=ni.08329238.1580414184&rt=1&rememberSortType=minDeparture&jumpToDetails=yes&HWAI=CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
db_link = 'https://reiseauskunft.bahn.de/bin/query.exe/dn?ld=43238&protocol=https:&seqnr=1&ident=ni.08329238.1580414184&rt=1&rememberSortType=minDeparture&jumpToDetails=yes&HWAI=CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;CONNECTION$C0-0!id=C0-0!HwaiConId=C0-0!HwaiDetailStatus=details!;CONNECTION$C0-1!id=C0-1!HwaiConId=C0-1!HwaiDetailStatus=details!;CONNECTION$C0-2!id=C0-2!HwaiConId=C0-2!HwaiDetailStatus=details!;'

# %%
# Make the GET request to a url
r = requests.get(db_link)
# Extract the content
c = r.content
# Create a soup object
soup = BeautifulSoup(c)
pprint.pprint(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Deutsche Bahn: bahn.de - Verbindungen - Ihre Auskunft</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="de" name="content-language"/>
# <meta content="noindex, follow" name="robots"/>
# <link href="https://www.img-bahn.de/s3/prod/v/img/favicon.ico" rel="shortcut icon"/>
# <script type="text/javascript">
# digitalData = new Object();
# digitalData.pageInstanceID  = "dbbahnprod_BAHN_AuskunftVerbindungenHinfahrt_de";
# digitalData.version         = "1.0";
# digitalData.reportSuite     = "dbbahnprod";
# digitalData.numberCarts     = 0;
# tmpDate                     = new Date();
# ...
